# %%
import timeit
from matplotlib import pyplot as plt
from tqdm import tqdm
import numpy as np
from functools import reduce
import operator
import jax
from jax import lax

# %%
from jax import tree_util
from graphax.sparse.block import BlockSparseTensor

def flatten_block_sparse_tensor(tensor):
    children = (tensor.blocks,)
    aux_data = (tensor.out_dims, tensor.primal_dims, tensor.out_shape, tensor.primal_shape, tensor.sparse_dims, tensor.pre_transforms, tensor.post_transforms)
    return children, aux_data

def unflatten_block_sparse_tensor(aux_data, children):
    blocks, = children
    out_dims, primal_dims, out_shape, primal_shape, sparse_dims, pre_transforms, post_transforms = aux_data
    return BlockSparseTensor(out_dims, primal_dims, out_shape, primal_shape, blocks, sparse_dims, pre_transforms, post_transforms)

tree_util.register_pytree_node(BlockSparseTensor, flatten_block_sparse_tensor, unflatten_block_sparse_tensor)

# %%
from jax import jit, make_jaxpr
from graphax.sparse.block import BlockSparseTensor, SparseDimension, DenseDimension, new_block_sparse_tensor
import jax.random as jrand

block_nums = 10
block_size = 10
k1, k2 = jrand.split(jrand.PRNGKey(42), 2)
x_blocks = jrand.normal(k1, (block_nums, block_size, block_size))
y_blocks = jrand.normal(k2, (block_nums, block_size, block_size))
x = new_block_sparse_tensor(
    [SparseDimension(0, block_nums, 0, 1, block_size)], 
    [SparseDimension(1, block_nums, 1, 0, block_size)], 
    (x_blocks-x_blocks.min())/x_blocks.max())
y = new_block_sparse_tensor(
    [SparseDimension(0, block_nums, 0, 1, block_size)], 
    [SparseDimension(1, block_nums, 1, 0, block_size)], 
    (y_blocks-x_blocks.min())/x_blocks.max())

jax.profiler.annotate_function
def matmul(a, b):
    return a @ b

jit_matmul = jit(matmul)

# %%
print(x,y,sep="\n\n")
# Out:
# BlockSparseTensor(
#     shape = (100 | 100),
#     out_dims = (
# 		SparseDimension(id=0, size=10, val_dim=0, other_id=1, block_size=10),
# 	),
#     primal_dims = (
# 		SparseDimension(id=1, size=10, val_dim=1, other_id=0, block_size=10),
# 	),
#     blocks = Array(shape=(10, 10, 10), dtype=float32),
#     sparse_dims = 1,
#     pre_transforms = [],
#     post_transforms = []
# )
#
# BlockSparseTensor(
#     shape = (100 | 100),
#     out_dims = (
# 		SparseDimension(id=0, size=10, val_dim=0, other_id=1, block_size=10),
# 	),
#     primal_dims = (
# 		SparseDimension(id=1, size=10, val_dim=1, other_id=0, block_size=10),
# 	),
#     blocks = Array(shape=(10, 10, 10), dtype=float32),
#     sparse_dims = 1,
#     pre_transforms = [],
#     post_transforms = []
# )

# %%
#%timeit jit_matmul(x, y)

# %%
x_, y_ = x.dense(), y.dense()
#%timeit jit_matmul(x_, y_)

# %%
import time
import jax
import jax.numpy as jnp

def profile_jax_fn(fn, *args, **kwargs):
    fn_jit = jax.jit(fn)
    out = fn_jit(*args, **kwargs).block_until_ready()
    
    backend = jax.lib.xla_bridge.get_backend()
    device = backend.devices()[0]
    
    mem_before = device.memory_allocated()
    
    start = time.time()
    out = fn_jit(*args, **kwargs).block_until_ready()
    end = time.time()
    
    mem_after = device.memory_allocated()
    
    return {
        "output": out,
        "time_sec": end - start,
        "mem_allocated_bytes": mem_after - mem_before,
    }

# %%
jaxpr = make_jaxpr(jit_matmul)(x_, y_)
print(jaxpr)
# Out:
# { lambda ; a:f32[100,100] b:f32[100,100]. let
#     c:f32[100,100] = jit[
#       name=matmul
#       jaxpr={ lambda ; a:f32[100,100] b:f32[100,100]. let
#           c:f32[100,100] = dot_general[
#             dimension_numbers=(([1], [0]), ([], []))
#             preferred_element_type=float32
#           ] a b
#         in (c,) }
#     ] a b
#   in (c,) }

# %%
jaxpr = make_jaxpr(jit_matmul)(x, y)
print(jaxpr)
# Out:
# { lambda ; a:f32[10,10,10] b:f32[10,10,10]. let
#     c:f32[10,10,10] = jit[
#       name=matmul
#       jaxpr={ lambda ; a:f32[10,10,10] b:f32[10,10,10]. let
#           c:f32[10,10,10] = dot_general[
#             dimension_numbers=(([2], [1]), ([0], [0]))
#           ] a b
#         in (c,) }
#     ] a b
#   in (c,) }

# %%
import matplotlib.colors as mcolors
viridis = plt.get_cmap('viridis')
cmap = mcolors.LinearSegmentedColormap.from_list(
    'custom_viridis', 
    [(1, 1, 1), *viridis(np.linspace(0, 1, 256))]
)

# %%
d = x.dense()
plt.matshow(d, cmap=cmap)
plt.show()

# %%
xb = (x_blocks-x_blocks.min())/x_blocks.max()
plt.matshow(xb[0], vmin=0, vmax=xb.max())
assert (xb[0] == d[:10,:10]).all()

# %%
import jax.numpy as jnp
from operator import mul
from functools import reduce
def gen_blocks(*shape):
    return jnp.arange(reduce(mul, shape)).reshape(shape)+1

# %%
blocks = gen_blocks(2,2,2)
bb = new_block_sparse_tensor(
    [SparseDimension(0, 2, 0, 1, 2)], 
    [SparseDimension(1, 2, 1, 0, 2)], 
    blocks
)
d = bb.dense()

# %%
plt.matshow(d, cmap=cmap)
plt.show()

# %%
plt.matshow(blocks[0], vmin=0, vmax=blocks.max())
plt.show()

# %%
blocks = gen_blocks(2, 2, 3)
bb = new_block_sparse_tensor(
    [SparseDimension(0, 2, 0, 1, 2)], 
    [SparseDimension(1, 2, 1, 0, 3)], 
    blocks
)
d = bb.dense()

# %%
ax = plt.matshow(d, cmap=cmap)
plt.show()

# %%
plt.matshow(blocks[0], vmin=0, vmax=blocks.max())
plt.show()

# %%
blocks = gen_blocks(2,2,2,2)
bb = new_block_sparse_tensor(
    [
        SparseDimension(0, 2, 0, 1, 2)
    ], [
        SparseDimension(1, 2, 1, 0, 2),
        DenseDimension(2, 2, 2)
    ], blocks)
d = bb.dense()

# %%
from matplotlib import colormaps
def matshow_3d(a, max_val):
    ax = plt.figure().add_subplot(projection='3d')
    ax.voxels(a, facecolors=colormaps["viridis"]((a/max_val)), shade=False)
    
    ax.set_aspect("equal")
    
    x=jnp.arange(a.shape[0])
    y=jnp.arange(a.shape[1])
    z=jnp.arange(a.shape[2])
    
    ax.set_xticks(x+0.5)
    ax.set_yticks(y+0.5)
    ax.set_zticks(z+0.5)
    
    ax.set_xticklabels(x)
    ax.set_yticklabels(y)
    ax.set_zticklabels(z)

    ax.grid(False)

# %%
matshow_3d(d, d.max())

plt.show()

# %%
matshow_3d(blocks[0], blocks.max())
plt.show()

# %%
a = bb.dense()
b = bb.T.dense()
c = lax.dot_general(b, a, (([2], [0]), ([], [])))
assert (c == jnp.einsum('ijk, klm -> ijlm', b, a)).all()

# %%
for i in range(c.shape[-1]):
    matshow_3d(c[...,i], c.max())

plt.show()

# %%
assert ((bb.T@bb).dense()==c).all()

# %%
c = lax.dot_general(a, b, (((1, 2),(0, 1)),((), ())))
assert (c == jnp.einsum('ijk, jkl -> il', a, b)).all()

# %%
plt.matshow(c, cmap=cmap)
plt.show()

# %%
assert ((bb@bb.T).dense()==c).all()

# %%
blocks = gen_blocks(2, 2, 2, 2, 2, 2)
bb = new_block_sparse_tensor(
    [
        SparseDimension(0, 2, 0, 2, 2),
        SparseDimension(1, 2, 1, 3, 2)
    ], [
        SparseDimension(2, 2, 2, 0, 2),
        SparseDimension(3, 2, 3, 1, 2)
    ], blocks)
d = bb.dense()

# %%
for i in range(d.shape[-1]):
    matshow_3d(d[...,i], d.max())

plt.show()

# %%
for i in range(blocks.shape[-1]):
    matshow_3d(blocks[0,0,...,i], blocks.max())

plt.show()

# %%
a = bb.dense()
b = bb.T.dense()
c = lax.dot_general(a, b, (((2, 3),(0, 1)),((), ())))
assert (c == jnp.einsum('ijkl, klmn -> ijmn', a, b)).all()

# %%
for i in range(c.shape[-1]):
    matshow_3d(c[...,i], c.max())

plt.show()

# %%
assert ((bb@bb.T).dense()==c).all()

# %%
c = lax.dot_general(b, a, (((2, 3),(0, 1)),((), ())))
assert (c == jnp.einsum('ijkl, klmn -> ijmn', b, a)).all()

# %%
blocks = gen_blocks(2, 3, 4, 3, 2, 1)
bb = new_block_sparse_tensor(
    [
        SparseDimension(0, 2, 0, 2, 4),
        SparseDimension(1, 3, 1, 3, 3)
    ], [
        SparseDimension(2, 2, 2, 0, 2),
        SparseDimension(3, 3, 3, 1, 1)
    ], blocks)
d = bb.dense()

# %%
for i in range(d.shape[-1]):
    matshow_3d(d[...,i], d.max())

plt.show()

# %%
blocks = gen_blocks(2,3,4,3,2,1).transpose(0,1,4,5,2,3)
bbT = new_block_sparse_tensor(
    [
        SparseDimension(0, 2, 0, 2, 2),
        SparseDimension(1, 3, 1, 3, 1)
    ], [
        SparseDimension(2, 2, 2, 0, 4),
        SparseDimension(3, 3, 3, 1, 3)
    ],
    blocks
)

# %%
print(bb.T, bbT, sep="\n\n")
# Out:
# BlockSparseTensor(
#     shape = (4, 3 | 8, 9),
#     out_dims = (
# 		SparseDimension(id=0, size=2, val_dim=2, other_id=2, block_size=2),
# 		SparseDimension(id=1, size=3, val_dim=3, other_id=3, block_size=1),
# 	),
#     primal_dims = (
# 		SparseDimension(id=2, size=2, val_dim=0, other_id=0, block_size=4),
# 		SparseDimension(id=3, size=3, val_dim=1, other_id=1, block_size=3),
# 	),
#     blocks = Array(shape=(2, 3, 4, 3, 2, 1), dtype=int32),
#     sparse_dims = 2,
#     pre_transforms = [],
#     post_transforms = []
# )
#
# BlockSparseTensor(
#     shape = (4, 3 | 8, 9),
#     out_dims = (
# 		SparseDimension(id=0, size=2, val_dim=0, other_id=2, block_size=2),
# 		SparseDimension(id=1, size=3, val_dim=1, other_id=3, block_size=1),
# 	),
#     primal_dims = (
# 		SparseDimension(id=2, size=2, val_dim=2, other_id=0, block_size=4),
# 		SparseDimension(id=3, size=3, val_dim=3, other_id=1, block_size=3),
# 	),
#     blocks = Array(shape=(2, 3, 2, 1, 4, 3), dtype=int32),
#     sparse_dims = 2,
#     pre_transforms = [],
#     post_transforms = []
# )

# %%
assert (bb.T.dense() == bbT.dense()).all()

# %%
a = bb.dense()
b = bb.T.dense()
c = lax.dot_general(a, b, (((2, 3),(0, 1)),((), ())))
assert (c == jnp.einsum('ijkl, klmn -> ijmn', a, b)).all()

# %%
for i in range(c.shape[-1]):
    matshow_3d(c[...,i], c.max())

plt.show()

# %%
assert ((bb@bb.T).dense()==c).all()

# %%
c = lax.dot_general(b, a, (((2, 3),(0, 1)),((), ())))
assert (c == jnp.einsum('ijkl, klmn -> ijmn', b, a)).all()

# %%
for i in range(c.shape[-1]):
    matshow_3d(c[...,i], c.max())

plt.show()

# %%
assert ((bb.T@bb).dense()==c).all()

# %%
blocks = gen_blocks(2, 3, 4, 3, 2, 1)
bb = new_block_sparse_tensor(
    [
        SparseDimension(0, 2, 0, 0, 4),
        SparseDimension(1, 3, 1, 1, 3)
    ], [
        SparseDimension(2, 2, 2, 2, 2),
        SparseDimension(3, 3, 3, 3, 1)
    ], blocks) # TODO not invariant in val_dim...
d = bb.dense()

# %%
import json
import os
import ast

res = {}
for run in os.listdir('data'):
    with open('data/' + run, "r") as f:
        cur = json.load(f)
    
    name = run.split('.', 2)[0]
    res_d1 = res[name] = {}
    
    for key1, val1 in list(cur.items()):
        key1 = ast.literal_eval(key1)
        res_d2 = res_d1[key1] = {}
        
        for key2, val2 in list(val1.items()):
        
            if name.endswith('_mul_sum'):
                val2 = tuple(val2)
            key2 = ast.literal_eval(key2)
            res_d2[key2] = val2

# %%
def get_title(key: str):
    return ' '.join([x if x.isupper() else x.capitalize() for x in key.split('_') ])

# %%
first_layer_keys = res.keys()
mul_sum_keys = set(key for key in first_layer_keys if key.endswith('mul_sum'))
exp_data_keys = first_layer_keys - mul_sum_keys
stat_operator = np.median

# %%
# Test memory at some point maybe even test time
# Test on CPU

# %%
block_shape_to_plot = (100, 100)
blocks = {key: [] for key in exp_data_keys}
times = {key: [] for key in exp_data_keys}

for key in exp_data_keys:
    for non_block_shape, block_shapes in res[key].items():
        if block_shape_to_plot in block_shapes:
            blocks[key].append(reduce(operator.mul, non_block_shape))
        times[key].append(stat_operator(block_shapes[block_shape_to_plot]))
    b, t = zip(*sorted(zip(blocks[key], times[key])))
    blocks[key] = np.array(b)
    times[key] = np.array(t)

plt.figure(figsize=(10, 6))

for key in exp_data_keys:
    plt.plot(blocks[key], times[key], marker='o', label=get_title(key))

plt.xlabel("Number of Blocks")
plt.ylabel("Time (seconds)")
plt.title(f"Time vs. Number of Blocks\n(Block shape = {block_shape_to_plot})")
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()

# %%
block_shape_to_plot = (100,100)
blocks = {key: [] for key in mul_sum_keys}
times = {key: [] for key in mul_sum_keys}

for key in mul_sum_keys:
    for non_block_shape, block_shapes in res[key].items():
        if block_shape_to_plot in block_shapes:
            blocks[key].append(reduce(operator.mul, non_block_shape))
            times[key].append(np.sum(block_shapes[block_shape_to_plot]))
    b, t = zip(*sorted(zip(blocks[key], times[key])))
    blocks[key] = np.array(b)
    times[key] = np.array(t)

plt.figure(figsize=(10, 6))

for key in mul_sum_keys:
    plt.plot(blocks[key], times[key], label=get_title(key.split('_',2)[0]))

plt.xlabel("Number of Blocks")
plt.ylabel("Operations")
plt.title(f"Operations vs. Number of Blocks\n(Block shape = {block_shape_to_plot})")
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()

# %%
non_block_shape_to_plot = (100,)
blocks = {key: [] for key in exp_data_keys}
times = {key: [] for key in exp_data_keys}

for key in exp_data_keys:
    if non_block_shape_to_plot in res[key]:
        block_shapes = res[key][non_block_shape_to_plot]
        for block_shape in block_shapes:
            blocks[key].append(reduce(operator.mul, block_shape))
            times[key].append(stat_operator(block_shapes[block_shape]))
    b, t = zip(*sorted(zip(blocks[key], times[key])))
    blocks[key] = np.array(b)
    times[key] = np.array(t)
        


plt.figure(figsize=(10, 6))

for key in exp_data_keys:
    plt.plot(blocks[key], times[key], marker='o', label=get_title(key))
    
plt.xlabel("Block Size")
plt.ylabel("Time (seconds)")
plt.title(f"Time vs. Block Size\n(Non-Blocks = {non_block_shape_to_plot})")
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()

# %%
non_block_shape_to_plot = (100,)
blocks = {key: [] for key in mul_sum_keys}
times = {key: [] for key in mul_sum_keys}

for key in mul_sum_keys:
    if non_block_shape_to_plot in res[key]:
        block_shapes = res[key][non_block_shape_to_plot]
        for block_shape in block_shapes:
            blocks[key].append(reduce(operator.mul, block_shape))
            times[key].append(stat_operator(block_shapes[block_shape]))
    b, t = zip(*sorted(zip(blocks[key], times[key])))
    blocks[key] = np.array(b)
    times[key] = np.array(t)


plt.figure(figsize=(10, 6))

for key in mul_sum_keys:
    plt.plot(blocks[key], times[key], label=get_title(key.split('_',2)[0]))
    
plt.xlabel("Block Size")
plt.ylabel("Operations")
plt.title(f"Operations vs. Block Size\n(Blocks = {non_block_shape_to_plot})")
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

heatmap_data = {key: [] for key in exp_data_keys}   
non_block_shapes_labels = sorted(next(iter(res.values())).keys())
block_shapes_labels = sorted(next(iter(next(iter(res.values())).values())))

for non_block_shapes in non_block_shapes_labels:
    rows = {key: [] for key in exp_data_keys}
    for block_shape in block_shapes_labels:
        for key in exp_data_keys:
            if block_shape in res[key][non_block_shapes]:
                rows[key].append(stat_operator(res[key][non_block_shapes][block_shape]))
            else:
                rows[key].append(np.nan)
    for key in exp_data_keys:
        heatmap_data[key].append(rows[key])
for key in exp_data_keys:
    heatmap_data[key] = np.array(heatmap_data[key])
    
fig, axes = plt.subplots(-(len(exp_data_keys)//-2), 2, figsize=(14, 12))

vmax = min([np.quantile(heatmap_data[key], 0.8) for key in exp_data_keys])
vmin = max([np.quantile(heatmap_data[key], 0.2) for key in exp_data_keys])

for i, key in enumerate(exp_data_keys):
    if len(exp_data_keys) >= 2:
        idx = [i // 2, i % 2]
    else:
        idx = [i]
    
    sns.heatmap(
        heatmap_data[key],
        ax=axes[*idx],
        xticklabels=block_shapes_labels,
        yticklabels=non_block_shapes_labels,
        vmin=vmin,
        vmax=vmax,
        norm=plt.matplotlib.colors.LogNorm(),
        cmap="viridis",
        cbar_kws={"label": "Time (seconds)"}
    )
    axes[*idx].set_xlabel("Non-Block Shape")
    axes[*idx].set_ylabel("Block Shape")
    axes[*idx].set_title(get_title(key))

if len(exp_data_keys) % 2:
    if len(exp_data_keys) >= 2:
        last_idx = [-(len(exp_data_keys)//-2) - 1, 1]
    else:
        last_idx = [1]
    axes[*last_idx].axis('off')

plt.tight_layout()

plt.show()

# %%
data = {key: {'time': [], 'ops': []} for key in exp_data_keys}  
for key1 in exp_data_keys:
    for key2, val2 in res[key1].items():
        for key3, val3 in val2.items():
            if key1.endswith('sparse'):
                if 'sparse_mul_sum' in res[key1]:
                    continue
            if key1.endswith('sparse'):
                ops = sum(res['sparse_mul_sum'][key2][key3])
            else:
                ops = sum(res['dense_mul_sum'][key2][key3])
            data[key1]['ops'].append(ops)
            data[key1]['time'].append(stat_operator(val3))

plt.figure(figsize=(10, 6))

for key in exp_data_keys:
    plt.scatter(data[key]['ops'], data[key]['time'], label=key.replace('_',' ').title(), marker="o")

# Customize the plot
plt.title("Median Runtimes vs Operations")
plt.xlabel("Number of Operations")
plt.ylabel("Median Runtime")
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
